# %%
#AFTER START RUNNING THIS PROGRAM JUST TRY TO SHOW WHITE BACKGROUND AND BLACK 
#FOREGROUND TEXT

#LIBRARIES NEEDED TO RUN


import cv2

import pytesseract
import  numpy as np
import pyttsx3
import say
import os
from pytesseract import image_to_string
from gtts import gTTS

pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files (x86)\\Tesseract-OCR\\tesseract.exe'

# %%
# The text that you want to convert to audio 
#mytext = 'Welcome to geeksforgeeks!ndlkvnosadnvoasfajsdfjafjsdfasdfsdmnoejfoejfpwepffjeojqjo'
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('rate', 130)     
engine.setProperty('voice',voices[0].id)

#FUNCTION THAT GOING TO RECOGONIZE THE TEXT TO RECOGONIZE I USED PYTESSERACT
#INSTEAD OF USING THE VIDEO FILE YOU CAN USE IMAGE TO RECOGNIZE BY PASSING

def recogonize(im):
    img=cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    (thresh, im_bw) = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    im_bw=cv2.cvtColor(im_bw,cv2.COLOR_GRAY2BGR)
    mytext=image_to_string(im_bw)
# Language in which you want to convert 
    language = 'en'
    
    engine.say(mytext)
    engine.runAndWait()
    return mytext

# %%
cap=cv2.VideoCapture(0)
skipframe=0
while True:
    ret,frame=cap.read()
    cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    if(skipframe%30==0):
        temp=recogonize(frame)
        print(temp)
    cv2.imshow('frame',frame)
    skipframe+=1
    if cv2.waitKey(1)&0xff==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 7 " s
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Merntse +
#
# rae 2 IDKHUL..S. 5.1
# nos prevented @ POPCT tt
#
# Jeuinpning:..SATH
# re SELIM, Senin AB DLE. E
# sin Computing and Communication Engine®
#
# ATO} Bannati Ammon Institute of Technology India
#
#
#
#
#
#
#
#
#
#
#
# + 6 RR,
# ssi
#
# Boosey ,
#
#
#
#
# Thes certificate is presented to
#
# rf ‘open Kumas 3$
#
#
#
# ree lech LE, Orme
#
#
# ernficate is presented t
#
#
#
#
#
#
# Ths
# Naver Kamas S
# lech 18 organized BY
#
# tes hn dogy Business [neu
# & 21" October,
#
#
#
#
#
#
# foe parespanng ts 11a
# vitb all
#
# Entrepreneurstrp C1
# inne wed ae 20"
#
# at Vellore Insnture of Teetinlugy J
#
# Skype
#
# — _ .. AthW ites Oy
# Congratulations on taking the first seep:
#
# towards a technical and entrepreneurial
#
# This certificate is presented to
# oy
# sea
# for participating in Hacker’
# Entrepreneurship Cell, VIT & VIT- Teel
# ellore Institute of Technology, Vellore
#
#
#
#
#
# PACES HM.
# senled o paper titted
# Contin ORME EXPRESSION DTA
#
# 2 ont munication Engineering
#
# 39 at Boreor Amman instaule of lechnalogy india
#
#
#
# urrortep av:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# — |
# s EXIT :
#
# a
#
#
#
# > 7
# EXIT
